# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv(r'C:\Users\PRANAY\Documents\FULL STACK DATA SCIENCE jigsaw document\Python for data science\stackoverflow-1.csv',sep=',',header=0, encoding="latin")
print (data.head())
# Out:
#    RespondentID         Country    Salary  YearsCodedJob  OpenSource  Hobby  \
# 0             3  United Kingdom  113750.0             20           1      1
# 1            15  United Kingdom  100000.0             20           0      1
# 2            18   United States  130000.0             20           1      1
# 3            19   United States   82500.0              3           0      1
# 4            26   United States  175000.0             16           0      1
#
#    CompanySizeNumber      Remote  CareerSatisfaction  Datascientist  ...  \
# 0            10000.0  Not remote                   8              0  ...
# 1             5000.0      Remote                   8              0  ...
# 2             1000.0      Remote                   9              0  ...
# 3            10000.0  Not remote                   5              0  ...
# 4            10000.0  Not remote                   7              0  ...
#
# ...

# %%
data.shape
# Out:
# (6991, 23)

# %%
data.isna().sum()
# Out:
# RespondentID                               0
# Country                                    0
# Salary                                     0
# YearsCodedJob                              0
# OpenSource                                 0
# Hobby                                      0
# CompanySizeNumber                         31
# Remote                                     0
# CareerSatisfaction                         0
# Datascientist                              0
# Database administrator                     0
# Desktop applications developer             0
# Developer with stats/math background       0
# DevOps                                     0
# Embedded developer                         0
# Graphic designer                           0
# Graphics programming                       0
# Machine learning specialist                0
# Mobile developer                           0
# Quality assurance engineer                 0
# Systems administrator                      0
# ...

# %%
data[(data['Country']=='India')&(data['Datascientist']==1)]
# Out:
#       RespondentID Country        Salary  YearsCodedJob  OpenSource  Hobby  \
# 569           3140   India   8809.279107              3           1      1
# 570           3145   India  32300.690060             10           0      0
# 591           3447   India   6606.959330              5           0      1
# 930           6056   India  17618.558210              2           1      1
# 1166          7656   India  11745.705480             10           0      1
# 1299          9340   India   4551.460872              2           0      0
# 1658         12083   India  17618.558210              2           1      1
# 1951         14115   India   1908.677140              1           0      1
# 2212         15212   India   9543.385700              2           0      1
# 2218         15270   India  14682.131850              4           0      1
# 2225         15360   India  30832.476880              3           0      1
# ...

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'United States', 'Germany', 'India', 'Canada'],
#       dtype=object)

# %%
data[(data['Country']=='Germany')&(data['YearsCodedJob']>10)]
# Out:
#       RespondentID  Country       Salary  YearsCodedJob  OpenSource  Hobby  \
# 13             103  Germany  83870.96774             17           1      1
# 168            928  Germany  64516.12903             16           0      1
# 189           1040  Germany  86021.50538             13           1      1
# 196           1087  Germany  69892.47312             15           0      0
# 204           1126  Germany  77419.35484             20           1      0
# ...            ...      ...          ...            ...         ...    ...
# 6849         50451  Germany  96774.19355             20           1      1
# 6861         50518  Germany  34946.23656             15           1      1
# 6929         50981  Germany  68817.20430             20           1      0
# 6944         51078  Germany  64516.12903             20           1      0
# 6962         51184  Germany  60215.05376             13           1      0
#
# ...

# %%
data.apply(lambda Remote: 1 if Remote['Remote']==1 else 0,axis=1)
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6986    0
# 6987    0
# 6988    0
# 6989    0
# 6990    0
# Length: 6991, dtype: int64

# %%
data.Remote.describe()
# Out:
# count           6991
# unique             2
# top       Not remote
# freq            6273
# Name: Remote, dtype: object

# %%
data['Mobile developer']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 6986    0
# 6987    1
# 6988    0
# 6989    0
# 6990    1
# Name: Mobile developer, Length: 6991, dtype: int64

# %%
def CompanySizeNumber(x):
    if x  < 20:
        print ('low')
    elif  20 > x < 1000:
        print ('median')
    else:
        print ('high')

# %%
data['CompanySizeNumber'].map(lambda x: "low" if x<20 elif 20> x<1000 "median" else "high")
# Out:
#   File "C:\Users\PRANAY\AppData\Local\Temp/ipykernel_8872/2341126447.py", line 1
#     data['CompanySizeNumber'].map(lambda x: "low" if x<20 elif 20> x<1000 "median" else "high")
#                                                           ^
# SyntaxError: invalid syntax

# %%
def get_label(x):
    if x<20:
        print ('low')
    elif 20> x<1000:
        print ('medain')
    else:
        print ('high')
data['CompanySizeNumber'].map(get_label)
data.apply(get_label,axis=1)
# Out:
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# low
# high
# low
# high
# high
# high
# low
# low
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# high
# high
# low
# low
# high
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# low
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# low
# high
# high
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# low
# high
# low
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# low
# high
# high
# low
# low
# high
# high
# high
# high
# high
# high
# high
# low
# high
# high
# high
# high
# high
# high
# high
# high
# low
# ...

# %%
data['CompanySizeNumber']
# Out:
# 0       10000.0
# 1        5000.0
# 2        1000.0
# 3       10000.0
# 4       10000.0
#          ...
# 6986    10000.0
# 6987        1.0
# 6988      100.0
# 6989      100.0
# 6990        1.0
# Name: CompanySizeNumber, Length: 6991, dtype: float64

# %%
data.groupby("Country")[['Remote']].agg(['max','sum'])
# Out:
#                Remote
#                   max  sum
# Country
# Canada              1   43
# Germany             1   49
# India               1   66
# United Kingdom      1   85
# United States       1  475

# %%
data[['Country','Remote']]
# Out:
#              Country      Remote
# 0     United Kingdom  Not remote
# 1     United Kingdom      Remote
# 2      United States      Remote
# 3      United States  Not remote
# 4      United States  Not remote
# ...              ...         ...
# 6986           India  Not remote
# 6987           India  Not remote
# 6988  United Kingdom  Not remote
# 6989   United States  Not remote
# 6990   United States  Not remote
#
# [6991 rows x 2 columns]

# %%
data['Remote'].replace(to_replace='Not remote',value=0,inplace=True)

# %%
data['Remote'].replace(to_replace='Remote',value=1,inplace=True)

# %%
data['Remote']
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 6986    0
# 6987    0
# 6988    0
# 6989    0
# 6990    0
# Name: Remote, Length: 6991, dtype: int64

# %%
data.describe()
# Out:
#        RespondentID         Salary  YearsCodedJob   OpenSource        Hobby  \
# count   6991.000000    6991.000000    6991.000000  6991.000000  6991.000000
# mean   26618.464597   72203.905007       7.494064     0.344443     0.759691
# std    15932.269919   40093.453720       6.009952     0.475220     0.427302
# min        3.000000    1101.159888       0.000000     0.000000     0.000000
# 25%    12841.000000   45000.000000       3.000000     0.000000     1.000000
# 50%    26533.000000   65000.000000       5.000000     0.000000     1.000000
# 75%    42056.000000  100000.000000      11.000000     1.000000     1.000000
# max    51391.000000  197000.000000      20.000000     1.000000     1.000000
#
#        CompanySizeNumber       Remote  CareerSatisfaction  Datascientist  \
# count        6960.000000  6991.000000         6991.000000    6991.000000
# mean         2099.409914     0.102703            7.578887       0.072093
# ...

# %%
data['Mobile developer'].sum()
# Out:
# 1356

# %%
(1356/6991)*100
# Out:
# 19.396366757259333

# %%
data['Web developer'].sum()
# Out:
# 5062

# %%
(5062/6991)*100
# Out:
# 72.40738091832355

# %%
data[(data['Mobile developer']==1)&(data['Remote']==1)&(data['Web developer']==1)]
# Out:
#       RespondentID         Country        Salary  YearsCodedJob  OpenSource  \
# 116            633   United States  115000.00000             20           1
# 118            644   United States  125000.00000              7           1
# 365           1898  United Kingdom   22500.00000              1           1
# 367           1908   United States   50000.00000              3           0
# 492           2620   United States  165000.00000             20           0
# ...            ...             ...           ...            ...         ...
# 6828         50373   United States  106000.00000             11           0
# 6861         50518         Germany   34946.23656             15           1
# 6873         50594   United States  140000.00000             20           0
# 6956         51136   United States   15000.00000              3           1
# 6959         51163           India   15416.23844              5           1
#
# ...
